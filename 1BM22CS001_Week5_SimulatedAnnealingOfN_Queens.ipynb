# %% [markdown]
# <a href="https://colab.research.google.com/github/Aakankshavr/AI-lab/blob/main/1BM22CS001_Week5_SimulatedAnnealingOfN_Queens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math

def initialize_board(n):
    return [random.randint(0, n - 1) for _ in range(n)]

def simulated_annealing(n, max_iterations=1000, initial_temp=100, cooling_rate=0.80):
    board = initialize_board(n)
    current_conflicts = find_conflicts(board)
    temperature = initial_temp
    min_temp = 1e-5
    max_deltaE = 100

    for iteration in range(max_iterations):
        if current_conflicts == 0:
            print(f"Iteration {iteration}: Solution found!")
            print("Board:", board)
            return board

        row = random.randint(0, n - 1)
        new_col = random.randint(0, n - 1)
        while new_col == board[row]:
            new_col = random.randint(0, n - 1)

        new_board = board[:]
        new_board[row] = new_col
        new_conflicts = find_conflicts(new_board)

        deltaE = new_conflicts - current_conflicts
        deltaE = max(min(deltaE, max_deltaE), -max_deltaE)

        if deltaE < 0 or math.exp(-deltaE / temperature) > random.random():
            board, current_conflicts = new_board, new_conflicts


        prob = math.exp(-deltaE / temperature) if temperature > min_temp else 1.0
        print(f"Probability: {prob}")

        print(f"Iteration {iteration}: Temperature={temperature:.2f}, Current Conflicts={current_conflicts}, "
              f"Delta E={deltaE},  Row {row} -> Column {new_col}\n")
        print("Board Position:", board)

        temperature = max(temperature * cooling_rate, min_temp)

    print("No solution found.")
    return None

def find_conflicts(board):
    conflicts = 0
    n = len(board)
    for i in range(n):
        for j in range(i + 1, n):
            if board[i] == board[j] or abs(board[i] - board[j]) == j - i:
                conflicts += 1
    return conflicts

n = 8
max_iterations = int(input("Enter the maximum number of iterations: "))
initial_temp = float(input("Enter the initial temperature: "))
cooling_rate = float(input("Enter the cooling rate (between 0 and 1): "))

solution = simulated_annealing(n, max_iterations, initial_temp, cooling_rate)
if solution:
    print("Final Solution:", solution)
else:
    print("No solution found.")
# Out:
# Enter the maximum number of iterations: 50
# Enter the initial temperature: 500
# Enter the cooling rate (between 0 and 1): 0.8
# Probability: 1.0
# Iteration 0: Temperature=500.00, Current Conflicts=8, Delta E=0,  Row 0 -> Column 3
#
# Board Position: [3, 6, 7, 0, 7, 4, 4, 0]
# Probability: 1.0025031276057952
# Iteration 1: Temperature=400.00, Current Conflicts=7, Delta E=-1,  Row 2 -> Column 4
#
# Board Position: [3, 6, 4, 0, 7, 4, 4, 0]
# Probability: 1.0
# Iteration 2: Temperature=320.00, Current Conflicts=7, Delta E=0,  Row 7 -> Column 6
#
# Board Position: [3, 6, 4, 0, 7, 4, 4, 6]
# Probability: 1.0
# Iteration 3: Temperature=256.00, Current Conflicts=7, Delta E=0,  Row 4 -> Column 0
#
# Board Position: [3, 6, 4, 0, 0, 4, 4, 6]
# Probability: 1.0048947528552166
# Iteration 4: Temperature=204.80, Current Conflicts=6, Delta E=-1,  Row 5 -> Column 0
#
# Board Position: [3, 6, 4, 0, 0, 0, 4, 6]
# Probability: 1.0
# Iteration 5: Temperature=163.84, Current Conflicts=6, Delta E=0,  Row 7 -> Column 5
#
# Board Position: [3, 6, 4, 0, 0, 0, 4, 5]
# Probability: 0.9848570363922593
# Iteration 6: Temperature=131.07, Current Conflicts=8, Delta E=2,  Row 0 -> Column 4
#
# Board Position: [4, 6, 4, 0, 0, 0, 4, 5]
# Probability: 1.0
# Iteration 7: Temperature=104.86, Current Conflicts=8, Delta E=0,  Row 5 -> Column 1
#
# Board Position: [4, 6, 4, 0, 0, 1, 4, 5]
# Probability: 0.9881498438136316
# Iteration 8: Temperature=83.89, Current Conflicts=9, Delta E=1,  Row 4 -> Column 2
#
# Board Position: [4, 6, 4, 0, 2, 1, 4, 5]
# Probability: 0.9852093117030912
# Iteration 9: Temperature=67.11, Current Conflicts=10, Delta E=1,  Row 3 -> Column 6
#
# Board Position: [4, 6, 4, 6, 2, 1, 4, 5]
# Probability: 0.9282020849305869
# Iteration 10: Temperature=53.69, Current Conflicts=14, Delta E=4,  Row 1 -> Column 5
#
# Board Position: [4, 5, 4, 6, 2, 1, 4, 5]
# Probability: 1.0476673576904922
# Iteration 11: Temperature=42.95, Current Conflicts=12, Delta E=-2,  Row 7 -> Column 1
#
# Board Position: [4, 5, 4, 6, 2, 1, 4, 1]
# Probability: 0.9713156070875452
# Iteration 12: Temperature=34.36, Current Conflicts=13, Delta E=1,  Row 3 -> Column 2
#
# Board Position: [4, 5, 4, 2, 2, 1, 4, 1]
# Probability: 0.9642740041674912
# Iteration 13: Temperature=27.49, Current Conflicts=14, Delta E=1,  Row 7 -> Column 3
#
# Board Position: [4, 5, 4, 2, 2, 1, 4, 3]
# Probability: 0.9555437439949742
# Iteration 14: Temperature=21.99, Current Conflicts=15, Delta E=1,  Row 0 -> Column 6
#
# Board Position: [6, 5, 4, 2, 2, 1, 4, 3]
# Probability: 0.8925374211734884
# Iteration 15: Temperature=17.59, Current Conflicts=17, Delta E=2,  Row 6 -> Column 0
#
# Board Position: [6, 5, 4, 2, 2, 1, 0, 3]
# Probability: 1.0
# Iteration 16: Temperature=14.07, Current Conflicts=17, Delta E=0,  Row 3 -> Column 4
#
# Board Position: [6, 5, 4, 4, 2, 1, 0, 3]
# Probability: 1.426567726419298
# Iteration 17: Temperature=11.26, Current Conflicts=13, Delta E=-4,  Row 0 -> Column 5
#
# Board Position: [5, 5, 4, 4, 2, 1, 0, 3]
# Probability: 1.1174198277903815
# Iteration 18: Temperature=9.01, Current Conflicts=12, Delta E=-1,  Row 6 -> Column 2
#
# Board Position: [5, 5, 4, 4, 2, 1, 2, 3]
# Probability: 0.7576333207034678
# Iteration 19: Temperature=7.21, Current Conflicts=14, Delta E=2,  Row 0 -> Column 4
#
# Board Position: [4, 5, 4, 4, 2, 1, 2, 3]
# Probability: 1.682729273501296
# Iteration 20: Temperature=5.76, Current Conflicts=11, Delta E=-3,  Row 6 -> Column 6
#
# Board Position: [4, 5, 4, 4, 2, 1, 6, 3]
# Probability: 1.2421458826912457
# Iteration 21: Temperature=4.61, Current Conflicts=10, Delta E=-1,  Row 1 -> Column 3
#
# Board Position: [4, 3, 4, 4, 2, 1, 6, 3]
# Probability: 1.3113413479945522
# Iteration 22: Temperature=3.69, Current Conflicts=9, Delta E=-1,  Row 0 -> Column 1
#
# Board Position: [1, 3, 4, 4, 2, 1, 6, 3]
# Probability: 1.4032811581952853
# Iteration 23: Temperature=2.95, Current Conflicts=8, Delta E=-1,  Row 5 -> Column 7
#
# Board Position: [1, 3, 4, 4, 2, 7, 6, 3]
# Probability: 0.428684977810923
# Iteration 24: Temperature=2.36, Current Conflicts=8, Delta E=2,  Row 4 -> Column 3
#
# Board Position: [1, 3, 4, 4, 2, 7, 6, 3]
# Probability: 0.5889608347438998
# Iteration 25: Temperature=1.89, Current Conflicts=9, Delta E=1,  Row 3 -> Column 1
#
# Board Position: [1, 3, 4, 1, 2, 7, 6, 3]
# Probability: 3.7565049107170014
# Iteration 26: Temperature=1.51, Current Conflicts=7, Delta E=-2,  Row 1 -> Column 5
#
# Board Position: [1, 5, 4, 1, 2, 7, 6, 3]
# Probability: 1.0
# Iteration 27: Temperature=1.21, Current Conflicts=7, Delta E=0,  Row 2 -> Column 2
#
# Board Position: [1, 5, 2, 1, 2, 7, 6, 3]
# Probability: 0.044962462810926675
# Iteration 28: Temperature=0.97, Current Conflicts=7, Delta E=3,  Row 1 -> Column 3
#
# Board Position: [1, 5, 2, 1, 2, 7, 6, 3]
# Probability: 1.0
# Iteration 29: Temperature=0.77, Current Conflicts=7, Delta E=0,  Row 1 -> Column 7
#
# Board Position: [1, 7, 2, 1, 2, 7, 6, 3]
# Probability: 1.0
# Iteration 30: Temperature=0.62, Current Conflicts=7, Delta E=0,  Row 4 -> Column 7
#
# Board Position: [1, 7, 2, 1, 7, 7, 6, 3]
# Probability: 7.534435538783507
# Iteration 31: Temperature=0.50, Current Conflicts=6, Delta E=-1,  Row 6 -> Column 3
#
# Board Position: [1, 7, 2, 1, 7, 7, 3, 3]
# Probability: 0.08010997532995931
# Iteration 32: Temperature=0.40, Current Conflicts=6, Delta E=1,  Row 1 -> Column 1
#
# Board Position: [1, 7, 2, 1, 7, 7, 3, 3]
# Probability: 550.5331882261208
# Iteration 33: Temperature=0.32, Current Conflicts=4, Delta E=-2,  Row 1 -> Column 6
#
# Board Position: [1, 6, 2, 1, 7, 7, 3, 3]
# Probability: 0.000374990805031641
# Iteration 34: Temperature=0.25, Current Conflicts=4, Delta E=2,  Row 2 -> Column 3
#
# Board Position: [1, 6, 2, 1, 7, 7, 3, 3]
# Probability: 5.218260713410751e-05
# Iteration 35: Temperature=0.20, Current Conflicts=4, Delta E=2,  Row 7 -> Column 7
#
# Board Position: [1, 6, 2, 1, 7, 7, 3, 3]
# Probability: 4.435138809354133e-06
# Iteration 36: Temperature=0.16, Current Conflicts=4, Delta E=2,  Row 4 -> Column 3
#
# Board Position: [1, 6, 2, 1, 7, 7, 3, 3]
# Probability: 0.0004511458954446188
# Iteration 37: Temperature=0.13, Current Conflicts=4, Delta E=1,  Row 7 -> Column 5
#
# Board Position: [1, 6, 2, 1, 7, 7, 3, 3]
# Probability: 6.575007659683783e-05
# Iteration 38: Temperature=0.10, Current Conflicts=4, Delta E=1,  Row 0 -> Column 2
#
# Board Position: [1, 6, 2, 1, 7, 7, 3, 3]
# Probability: 3.505424823357716e-11
# Iteration 39: Temperature=0.08, Current Conflicts=4, Delta E=2,  Row 2 -> Column 3
#
# Board Position: [1, 6, 2, 1, 7, 7, 3, 3]
# Probability: 2.920538334544293e-07
# Iteration 40: Temperature=0.07, Current Conflicts=4, Delta E=1,  Row 2 -> Column 5
#
# Board Position: [1, 6, 2, 1, 7, 7, 3, 3]
# Probability: 6.789356896725817e-09
# Iteration 41: Temperature=0.05, Current Conflicts=4, Delta E=1,  Row 1 -> Column 0
#
# Board Position: [1, 6, 2, 1, 7, 7, 3, 3]
# Probability: 6.162909617239835e-11
# Iteration 42: Temperature=0.04, Current Conflicts=4, Delta E=1,  Row 6 -> Column 2
#
# Board Position: [1, 6, 2, 1, 7, 7, 3, 3]
# Probability: 1.0
# Iteration 43: Temperature=0.03, Current Conflicts=4, Delta E=0,  Row 7 -> Column 0
#
# Board Position: [1, 6, 2, 1, 7, 7, 3, 0]
# Probability: 1.0
# Iteration 44: Temperature=0.03, Current Conflicts=4, Delta E=0,  Row 2 -> Column 6
#
# Board Position: [1, 6, 6, 1, 7, 7, 3, 0]
# Probability: 1.14333997426214e-20
# Iteration 45: Temperature=0.02, Current Conflicts=4, Delta E=1,  Row 1 -> Column 7
#
# Board Position: [1, 6, 6, 1, 7, 7, 3, 0]
# Probability: 1.1822769834675477e-25
# Iteration 46: Temperature=0.02, Current Conflicts=4, Delta E=1,  Row 0 -> Column 4
#
# Board Position: [1, 6, 6, 1, 7, 7, 3, 0]
# Probability: 1.0
# Iteration 47: Temperature=0.01, Current Conflicts=4, Delta E=0,  Row 4 -> Column 2
#
# Board Position: [1, 6, 6, 1, 2, 7, 3, 0]
# Probability: 1.2654576304485496e-78
# Iteration 48: Temperature=0.01, Current Conflicts=4, Delta E=2,  Row 4 -> Column 1
#
# Board Position: [1, 6, 6, 1, 2, 7, 3, 0]
# Probability: 8.744082904837821e-147
# Iteration 49: Temperature=0.01, Current Conflicts=4, Delta E=3,  Row 5 -> Column 1
#
# Board Position: [1, 6, 6, 1, 2, 7, 3, 0]
# No solution found.
# No solution found.
